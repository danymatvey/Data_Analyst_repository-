# %% [markdown]
# Привет, меня зовут Люман Аблаев. Сегодня я проверю твой проект.
# <br> Дальнейшее общение будет происходить на "ты" если это не вызывает никаких проблем.
# <br> Желательно реагировать на красные комментарии ('исправил', 'не понятно как исправить ошибку', ...)
# <br> Пожалуйста, не удаляй комментарии ревьюера, так как они повышают качество повторного ревью.
#
# Комментарии будут в <font color='green'>зеленой</font>, <font color='blue'>синей</font> или <font color='red'>красной</font> рамках:
#
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Если все сделано отлично
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Совет: </b> Если можно немного улучшить
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Если требуются исправления. Работа не может быть принята с красными комментариями.
# </div>
#
# -------------------
#
# Будет очень хорошо, если ты будешь помечать свои действия следующим образом:
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента:</b> ...
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Изменения:</b> Были внесены следующие изменения ...
# </div>
#
# <font color='orange' style='font-size:24px; font-weight:bold'>Общее впечатление</font>
# * Спасибо за такую хорошую работу, мне она очень понравилась
# - Я оставил некоторые советы, надеюсь они будут полезными или интересными.
# - Есть небольшие недочеты, но думаю у тебя не составить труда их исправить
# - Особенно важно поправть ошибку с дублированием кода в каждой ячейки - это ключевое. Не нужно снова подгружать данные каждую ячейку.
# - Жду обновленную работу!
#
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента к правке 1:</b> Приветствую, Люман! Рад с тобой познакомиться. Буду оформлять свои комментарии тут, но дописывать номер правки. Например: Комментарий студента к правке 1. Чтобы не запутаться:)
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Изменения к правке 1:</b> А изменения тут:)
# </div>

# %% [markdown]
# <font color='orange' style='font-size:24px; font-weight:bold'>Общее впечатление[2]</font>
# * Спасибо за оперативность
# - Приятно видеть фидбек
# - Недочеты исправлены - работа полностью корректна
# - Рад был быть полезен. Удачи в дальнейшем обучении!

# %% [markdown]
# # Проект спринта 7. Изучение развития игровой индустрии в начале XXI века
#
# - Автор: Матвеев Д., группа DA-123
# - Дата: 12.06.2025 г.

# %% [markdown]
# ### Цели и задачи проекта
#
# <font color='#777778'>Целью проекта является желание привлечь новую аудиторию и подготовить статью о развитии индустрии игр в начале XXI века. В статье-исследовании хотят сделать обзор игровых платформ, изучить объёмы продаж игр разных жанров и региональные предпочтения игроков.
# Для статьи понадобится изучить развитие игровой индустрии с 2000 по 2013 год. В начале XXI века индустрия игр активно росла: развивались игровые платформы и появлялись мощные консоли, возникало множество игровых жанров, а также росло количество многопользовательских онлайн-игр и сообществ.
# Анализ будет проводиться с историческими данными, собранными из открытых источников. В них есть информация о продажах игр, сделанных в разных жанрах и выпущенных на разных платформах, а также пользовательские и экспертные оценки игр.</font>

# %% [markdown]
# ### Описание данных
#
# <font color='#777778'>Данные /datasets/new_games.csv содержат информацию о продажах игр разных жанров и платформ, а также пользовательские и экспертные оценки игр:
# - Name — название игры.
# - Platform — название платформы.
# - Year of Release — год выпуска игры.
# - Genre — жанр игры.
# - NA sales — продажи в Северной Америке (в миллионах проданных копий).
# - EU sales — продажи в Европе (в миллионах проданных копий).
# - JP sales — продажи в Японии (в миллионах проданных копий).
# - Other sales — продажи в других странах (в миллионах проданных копий).
# - Critic Score — оценка критиков (от 0 до 100).
# - User Score — оценка пользователей (от 0 до 10).
# - Rating — рейтинг организации ESRB (англ. Entertainment Software Rating Board). </font>

# %% [markdown]
# ### Содержимое проекта
#
# <font color='#777778'>Основные шаги проекта следующие:
# - Загрузка и знакомство с данными;
# - Проверка ошибок в данных и их предобработка;
# - Фильтрация данных;
# - Категоризация данных;
# - Вывод по результатам анализа.
# </font>
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Подробное вступление, ознакомились и идем дальше.
# </div>

# %% [markdown]
# ## 1. Загрузка данных и знакомство с ними
#
# - Загрузите необходимые библиотеки Python и данные датасета `/datasets/new_games.csv`.

# %%
import pandas as pd
df = pd.read_csv('/datasets/new_games.csv')
display(df)

# %% [markdown]
# <div class="alert alert-info">
# <b>Совет:</b>
#
# Здесь если выводить таблицу не через print(), а через display(), будет удобнее все воспринимать.
#
# Важно поправить этот момент во всем проекте
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента к правке 1:</b> Не знал или забыл про эту функцию. Выглядит действительно гораздо приятнее, спасибо за совет!
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Изменения к правке 1:</b> Были внесены следующие изменения: вывод таблицы через display(), а не через print().
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Успех[2]:</b> 👍
# </div>

# %% [markdown]
# - Познакомьтесь с данными: выведите первые строки и результат метода `info()`.

# %% [markdown]
#  <div class="alert alert-block alert-danger">
# <b>Ошибка:</b> Так. Я вижу ошибку, которая многократно повторяется, пожалуйста исправь ее везде ниже, я этот коментарий дублировать не буду.
#
# Суть ошибки:
#
# - Импорты и загрузку данных мы делаем один раз в проекте, и дальше работаем с переменной df, повторно выполнять данные действия не нужно и даже ошибочно. Поправь это везде.
# - Из-за того, что ты заново подгружаешь данные в каждой ячейки - у тебя затираются предыдущие операции. То есть не нужно повторять каждый раз все предыдущие действия (изменения формата колонок, типов данных, пропусков и т.п.) - это все делается 1 раз в проекте, не больше. А у тебя ячейки как снежный ком из-за этого растут в объеме
#  </div>
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента к правке 1:</b> Понимаю, но это я сделал из-за того, что еще не привык работать в Юпитере, поэтому, чтобы не потерять всю предобработку данных копировал весь код и добавлял в конце необходимые операции для того, чтобы ответить на вопрос.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Изменения к правке 1:</b> В дальнейшем не буду копировать весь код и буду оставлять только нужный код.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Успех[2]:</b> Принял, привыкай)
# </div>

# %%
import pandas as pd
df = pd.read_csv('/datasets/new_games.csv')
display(df.head(), df.info())

# %% [markdown]
# <div class="alert alert-info">
# <b>Совет[2]:</b> Здесь уже импорты и подгрузка не нужны)
# </div>

# %% [markdown]
# - Сделайте вывод о полученных данных: данные какого объёма вам предоставили, соответствуют ли они описанию, встречаются ли в них пропуски, используются ли верные типы данных.
# - Отметьте другие особенности данных, которые вы обнаружили и на которые стоит обратить внимание при предобработке. Например, вы можете проверить названия столбцов: все ли названия отражают содержимое данных и прописаны в удобном для работы виде.

# %% [markdown]
# <font color='#777778'>После выгрузки данных видно, что данных храняться в массиве: 16 956 строк и 11 столбцов. Соответствуют описанию. В некоторых столбцах неверные типы данных (object), что потребует их изменение. Пропусков достаточно много - в основном в столбцах с оценками и рейтингом. Почти все названия столбцов требуется привезти к одному виду, т.к. все написаны в разных регистрах.
#
# Из особенностей видно по первым строкам - в некорректном типе отображаются многие данные, например:
# - EU sales, JP sales, User Score,Rating в типе object;
# - Year of Release в типе float64;
#
# </font>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b>  👍 Все так. В данных есть пропуски, можно поправить по стилю названий колонок, а также обязательно нужно разобраться в проблемах с несоответствием типов данных содержанию столбцов.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента к правке 1:</b> Спасибо!
# </div>

# %% [markdown]
# ---
#
# ## 2.  Проверка ошибок в данных и их предобработка
#
#
# ### 2.1. Названия, или метки, столбцов датафрейма
#
# - Выведите на экран названия всех столбцов датафрейма и проверьте их стиль написания.
# - Приведите все столбцы к стилю snake case. Названия должны быть в нижнем регистре, а вместо пробелов — подчёркивания.

# %%
display(f"Исходные названия столбцов:")
display(df.columns.tolist())

df.columns = (
    df.columns.str.lower()      
    .str.replace(' ', '_')       
    .str.replace('(', '')       
    .str.replace(')', '')
)

display(f"Новые названия столбцов (стиль snake_case):")
display(df.columns.tolist())

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Молодец, что  столбцы приведены к правильному формату, через функцию replace, а не проделано это вручную.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента к правке 1:</b> Не зря же проходили на курсе, полезная штука. Но с переводом в стиль snake_case я помучался с нужной последовательностью комбинаций...
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Успех[2]:</b> Первый раз помучался - следубщий раз будет просто)
# </div>

# %% [markdown]
# ### 2.2. Типы данных
#
# - Если встречаются некорректные типы данных, предположите их причины.
# - При необходимости проведите преобразование типов данных. Помните, что столбцы с числовыми данными и пропусками нельзя преобразовать к типу `int64`. Сначала вам понадобится обработать пропуски, а затем преобразовать типы данных.

# %%
df['year_of_release'] = pd.to_numeric(df['year_of_release'], errors='coerce').dropna().astype('Int64')
df['eu_sales'] = pd.to_numeric(df['eu_sales'], errors='coerce').dropna().astype('float64')
df['jp_sales'] = pd.to_numeric(df['jp_sales'], errors='coerce').dropna().astype('float64')
df['user_score'] = pd.to_numeric(df['user_score'], errors='coerce').dropna().astype('float64')


display (df.head(), df.info())

# %% [markdown]
# - В числовых столбцах могут встретиться строковые значения, например `unknown` или другие. Приводите такие столбцы к числовому типу данных, заменив строковые значения на пропуски.

# %% [markdown]
# <font color='#777778'>Все столбцы приведены к нужным типам.
#
# </font>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b>  С типами данных разобрались корректно </div>
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента к правке 1:</b> Отлично! Немного переживал из-за типов, особенно в колонке с годом выпуска. Однако посмотрев на данные, подумал, что будет проще обрабатывать в дальнейшем с помощью типа int.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Успех[2]:</b> Верно

# %% [markdown]
# ### 2.3. Наличие пропусков в данных
#
# - Посчитайте количество пропусков в каждом столбце в абсолютных и относительных значениях.

# %%
print (f"Количество пропусков в абсолютных значениях: {df.isna().sum()}")
print (f"Количество пропусков в относительных значениях: {df.isna().sum() / len(df)*100}")

# %% [markdown]
# - Изучите данные с пропущенными значениями. Напишите промежуточный вывод: для каких столбцов характерны пропуски и сколько их. Предположите, почему пропуски могли возникнуть. Укажите, какие действия с этими данными можно сделать и почему.

# %% [markdown]
# <font color='#777778'>Для разных столбцов пропуски имеют различный характер:
# - name, genre, eu_sales и jp_sales: очень малое количество пропусков. Вероятно забыли зафиксировать при загрузке данных;
# - year_of_release: 275 пропусков (1,6%). Пропуски в пределах допустимых 2%, поэтому предполагаю, что тоже ошибка при загрузке данных;
# - critic_score, user_score, rating: от 40 до 55% данных пропущено. Предполагаю, что недостаточное количество рейтинга и оценок пользователей связано с продажами, что в свою очередь связано с популярностью игры.
#
# Продажи высокие (игра популярная)- есть оценка и рейтинг, продажи низкие (игра непопулярная) - нет оценки и рейтинга.
#
# Принимается поступить так:
# - пропуски в name: удалить (не повлияют на анализ);
# - пропуски в genre: удалить (не повлияют на анализ);
# - пропуски в eu_sales: удалить (практически не повлияют на анализ);
# - пропуски в jp_sales: удалить (практически не повлияют на анализ);
# - пропуски в year_of_release: удалить (маловероятно, что повлияют на анализ);
# - пропуски в critic_score: ничего не делать;
# - пропуски в user_score: ничего не делать;
# - пропуски в rating: ничего не делать (не участвуют в анализе);
#
# </font>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Успех:</b>  Проведен корректный анализ пропусков, объяснены их возможные причины и предложены разумные способы обработки.
#
# По гипотезам, добавлю,  что, здесь может быть гипотеза в том, что для слишком старых игр или для игр из других регионов, не переведенных на английский язык, не существует достаточного количества оценок критиков и пользователей по естественным причинам.
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Ошибка:</b> Удалять rating не желательно - теряем большое количество данных.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента к правке 1:</b> Колебался сам по поводу rating, понимаю, что часть данных уходит, однако принял решение его все же убрать, поскольку они не участвуют в анализе.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Изменения к правке 1:</b> rating - не буду удалять. Исправил это также в тексте.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Успех[2]:</b> 👍
# </div>

# %% [markdown]
# - Обработайте пропущенные значения. Для каждого случая вы можете выбрать оптимальный, на ваш взгляд, вариант: заменить на определённое значение, оставить как есть или удалить.
# - Если вы решите заменить пропуски на значение-индикатор, то убедитесь, что предложенное значение не может быть использовано в данных.
# - Если вы нашли пропуски в данных с количеством проданных копий игры в том или ином регионе, их можно заменить на среднее значение в зависимости от названия платформы и года выхода игры.

# %%
df = df.dropna(subset=['name', 'genre','eu_sales','jp_sales','year_of_release'])

display (df.head(),df.tail())

# %% [markdown]
# <font color='#777778'>Пропуски в датафрейме обработаны.
# </font>

# %% [markdown]
# ### 2.4. Явные и неявные дубликаты в данных
#
# - Изучите уникальные значения в категориальных данных, например с названиями жанра игры, платформы, рейтинга и года выпуска. Проверьте, встречаются ли среди данных неявные дубликаты, связанные с опечатками или разным способом написания.
# - При необходимости проведите нормализацию данных с текстовыми значениями. Названия или жанры игр можно привести к нижнему регистру, а названия рейтинга — к верхнему.

# %%
initial_row_count = df.shape[0]
df_sorted = df.sort_values(by=list(df.columns))
unique_df = df.nunique()


df = df.dropna(subset=['name', 'genre','eu_sales','jp_sales','year_of_release','rating'])
final_row_count = df.shape[0]

unique_name = df['name'].unique()
unique_genre = df['genre'].unique() 
unique_platform = df['platform'].unique() 
unique_rating = df['rating'].unique() 
unique_year_of_release = df['year_of_release'].unique() 




print(f"Перечень уникальных названий: {unique_name}")
print(f"Перечень уникальных жанров: {unique_genre}")
print(f"Перечень уникальных платформ: {unique_platform}")
print(f"Перечень уникальных значений рейтинга: {unique_rating}")
print(f"Перечень уникальных годов выпуска: {unique_year_of_release}")
print(f"Количество строк до удаления дубликатов: {initial_row_count}")
print(f"Количество найденных дубликатов: {unique_df}")
print(f"Количество строк после удаления дубликатов : {final_row_count}")
print(f"Количество удалённых строк в абсолютном значении: {initial_row_count-final_row_count}")
print(f"Количество удалённых строк в относительном значении: {100-final_row_count/initial_row_count*100}")

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Совет:</b> Лаконичнее делать через цикл
#
#     for column in ['platform','year_of_release','genre','rating']:
#         print(f'Уникальные значения в столбце {column}:')
#         print(df[column].sort_values().unique())
#         print()
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента к правке 1:</b> Не очень въехал в циклы, поэтому оставлю как есть. Спасибо за совет, буду иметь в виду!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Успех[2]:</b> Старайся вьезжать - ведь это самая база, без циклов и функций никуда.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Успех:</b> С явными  и не явными дубликатами тоже разобрались корректно.
# </div>
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента к правке 1:</b> Спасибо!
# </div>

# %% [markdown]
# - После того как нормализуете данные и устраните неявные дубликаты, проверьте наличие явных дубликатов в данных.

# %% [markdown]
# - Напишите промежуточный вывод: укажите количество найденных дубликатов и действия по их обработке.

# %% [markdown]
# <font color='#777778'> Найдено 6777 дубликатов. Данные удалены, так как мешают анализу данных. Для обработке датафрейма использована сортировка по столбцам, приведение данных к нужному регистру, замена данных. Другие методы не использованы, потому что с помощью этих был получен нужный датафрейм для анализа.
# </font>

# %% [markdown]
# - В процессе подготовки данных вы могли что-либо удалять, например строки с пропусками или ошибками, дубликаты и прочее. В этом случае посчитайте количество удалённых строк в абсолютном и относительном значениях.

# %% [markdown]
# <font color='#777778'> Найдено 6777 дубликата, они же - удаленные строки в абсолютном количестве. В относительном значении - 40,66%.
# </font>

# %% [markdown]
# - После проведения предобработки данных напишите общий промежуточный вывод.

# %% [markdown]
# <font color='#777778'> Данные предобработаны, значения понятны и готовы к обработке. Выделены года, корректный перечень рейтингов, названий игр, видов платформ, жанры.
# </font>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> корректно считаетсся процент и доля отфильтрованных данных и сделаны соответствующие выводы.</div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента к правке 1:</b> Спасибо. Цифры чуть изменились - подкорректировал в тексте.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Успех[2]:</b> 👍
# </div>

# %% [markdown]
# ---
#
# ## 3. Фильтрация данных
#
# Коллеги хотят изучить историю продаж игр в начале XXI века, и их интересует период с 2000 по 2013 год включительно. Отберите данные по этому показателю. Сохраните новый срез данных в отдельном датафрейме, например `df_actual`.

# %%
df_actual = df[df['year_of_release'].between(2000, 2013)]

print(f"Всего записей в исходных данных: {len(df)}")
print(f"Отобрано записей за 2000-2013 гг.: {len(df_actual)}")
print(f"Распределение по годам:")
print(df_actual['year_of_release'].value_counts().sort_index())

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Решение через between очень лаконичное</div>
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента к правке 1:</b> Спасибо.
# </div>

# %% [markdown]
# ---
#
# ## 4. Категоризация данных
#
# Проведите категоризацию данных:
# - Разделите все игры по оценкам пользователей и выделите такие категории: высокая оценка (от 8 до 10 включительно), средняя оценка (от 3 до 8, не включая правую границу интервала) и низкая оценка (от 0 до 3, не включая правую границу интервала).

# %%
df_actual['user_score'] = pd.cut(df['user_score'], bins=[0, 3, 8, 10], labels=["Низкая оценка", "Средняя оценка", "Высокая оценка"],right=False)

display (df_actual)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Ошибка:</b>
#
# 1) Категоризацию  важно применять уже к актуальному периоду. Мы здесь исследуем актуальный период: смотрим распределение оценок и топ платформ.
#
# 2) Важно указывать right=False, чтобы не включать правую границу
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента к правке 1:</b> Принято.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Изменения к правке 1:</b> В код pd.cut по столбцу user_score добавлено right=False.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Успех[2]:</b> 👍 Есть контакт
# </div>

# %% [markdown]
# - Разделите все игры по оценкам критиков и выделите такие категории: высокая оценка (от 80 до 100 включительно), средняя оценка (от 30 до 80, не включая правую границу интервала) и низкая оценка (от 0 до 30, не включая правую границу интервала).

# %%
df_actual['critic_score'] = pd.cut(df['critic_score'], bins=[0, 30, 80, 100], labels=["Низкая оценка", "Средняя оценка", "Высокая оценка"],right=False)

display (df_actual)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Ошибка:</b>  Тоже самое
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента к правке 1:</b> Принято.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Изменения к правке 1:</b> В код pd.cut по столбцу critic_score добавлено right=False.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Успех[2]:</b> 👍
# </div>

# %% [markdown]
# - После категоризации данных проверьте результат: сгруппируйте данные по выделенным категориям и посчитайте количество игр в каждой категории.

# %%
user_score_count = df_actual['user_score'].value_counts().sort_index()
critic_score_count = df_actual['critic_score'].value_counts().sort_index()


print (f" Распределение игр по категориям user_score: {user_score_count}")
print (f" Распределение игр по категориям critic_score: {critic_score_count}")

# %% [markdown]
# - Выделите топ-7 платформ по количеству игр, выпущенных за весь актуальный период.

# %%
top_platform = df_actual['platform'].value_counts().head(7)


print (top_platform)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех[2]:</b> Категоризация проделана успешно. Все необходимые статистики корректно отображены.
# </div>

# %% [markdown]
# ---
#
# ## 5. Итоговый вывод
#
# В конце напишите основной вывод и отразите, какую работу проделали. Не забудьте указать описание среза данных и новых полей, которые добавили в исходный датасет.

# %% [markdown]
# <font color='#777778'> По результатам проведенного анализа определены следующие результаты.
#     Был дан массив информации  с историческими данными, которые коллеги собрали из открытых источников. В них есть информация о продажах игр, сделанных в разных жанрах и выпущенных на разных платформах, а также пользовательские и экспертные оценки игр. По ним создан датафрейм, проведена предобработка - нормализация значений, переименование и замена позиций, приведение к единому стилю, поиск и удалений дубликатов и ненужных данных для анализа.
#
#     По задумке важно было проанализировать срез данных в период с 2000 по 2013 годы, а также разделить игры на несколько категорий оценок пользователей и критиков, выделить топ-7 самых популярных платформ.
#
#     После группировки и категоризации пользовательских оценок видно, что в подавляющем большинстве игроки довольны играми, в основом игры получили среднюю (больше половины) и высокие оценки. Мало игр с низкими оценками.
#     Распределение следующее:
# - Низкая оценка (0-3 баллов): 117
# - Средняя оценка (3-8 баллов: 4115
# - Высокая оценка (8-10 баллов): 2290.
#
#      После группировки и категоризации оценок критиков видно, что мнение критиков совпадает с мнением игроков и распределение похожи - в подавляющем большинстве критики положительно оценили игры: средняя оценка у большей части игр, затем по количеству игры с высокими оценками. Мало игр с низкими оценками также мало.
#     Распределение следующее:
# - Низкая оценка (0-30 баллов): 55
# - Средняя оценка (30-80 баллов: 5463
# - Высокая оценка (80-100 баллов): 1695.
#
#     Самые популярные платформы, на которых выпускались игры следующие:
# - PS2: 1473 игр;
# - DS: 1265 игр;
# - Wii: 980 игр;
# - X360: 951 игр;
# - PS3: 833 игр;
# - XB: 728 игр;
# - PC: 635 игр.
#
#     Самой популярной платформой является PS2.
# </font>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Всегда приятно наблюдать подробный и структурированный итоговый вывод в конце работы!
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий студента к правке 1:</b> А мне то как приятно, что все получилось и результат правильный! Надеюсь 2-й правки не будет и буду чилить до следующей темы:)
#     Кстати - хороших праздников!
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Изменения к правке 1:</b> Немного подкорректировал цифры.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Успех[2]:</b> 🤝 Взаимно
# </div>
